# %% [raw]
# <script>
#   jQuery(document).ready(function($) {
#
#   $(window).on('load', function(){
#     $('#preloader').fadeOut('slow',function(){$(this).remove();});
#   });
#
#   });
# </script>
#
# <style type="text/css">
#   div#preloader { position: fixed;
#       left: 0;
#       top: 0;
#       z-index: 999;
#       width: 100%;
#       height: 100%;
#       overflow: visible;
#       background: #fff url('http://preloaders.net/preloaders/720/Moving%20line.gif') no-repeat center center;
#   }
#
# </style>
#
# <div id="preloader">
#
# </div>

# %% [raw]
# <script>
#   function code_toggle() {
#     if (code_shown){
#       $('div.input').hide('500');
#       $('#toggleButton').val('Show Code')
#     } else {
#       $('div.input').show('500');
#       $('#toggleButton').val('Hide Code')
#     }
#     code_shown = !code_shown
#   }
#
#   $( document ).ready(function(){
#     code_shown=false;
#     $('div.input').hide()
#   });
# </script>
# <form action="javascript:code_toggle()"><input type="submit" id="toggleButton" value="Show Code"></form>

# %% [markdown]
# # Table of Contents
#  <p><div class="lev1 toc-item"><a href="#Datos-espaciales" data-toc-modified-id="Datos-espaciales-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Datos espaciales</a></div><div class="lev2 toc-item"><a href="#Tipos-y-representaciones-de-datos" data-toc-modified-id="Tipos-y-representaciones-de-datos-11"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Tipos y representaciones de datos</a></div><div class="lev2 toc-item"><a href="#Procesos-de-puntos" data-toc-modified-id="Procesos-de-puntos-12"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Procesos de puntos</a></div><div class="lev3 toc-item"><a href="#John-Snow" data-toc-modified-id="John-Snow-121"><span class="toc-item-num">1.2.1&nbsp;&nbsp;</span>John Snow</a></div><div class="lev3 toc-item"><a href="#Ejemplo-datos-reales:-observaciones-de-jaguar" data-toc-modified-id="Ejemplo-datos-reales:-observaciones-de-jaguar-122"><span class="toc-item-num">1.2.2&nbsp;&nbsp;</span>Ejemplo datos reales: observaciones de jaguar</a></div><div class="lev1 toc-item"><a href="#Probabilidad-y-estadística" data-toc-modified-id="Probabilidad-y-estadística-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Probabilidad y estadística</a></div><div class="lev2 toc-item"><a href="#Variables-aleatorias" data-toc-modified-id="Variables-aleatorias-21"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Variables aleatorias</a></div><div class="lev2 toc-item"><a href="#Funciones-de-densidad/masa-de-probabilidad" data-toc-modified-id="Funciones-de-densidad/masa-de-probabilidad-22"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Funciones de densidad/masa de probabilidad</a></div><div class="lev3 toc-item"><a href="#Uniforme,-Bernoulli,-Binomial" data-toc-modified-id="Uniforme,-Bernoulli,-Binomial-221"><span class="toc-item-num">2.2.1&nbsp;&nbsp;</span>Uniforme, Bernoulli, Binomial</a></div><div class="lev3 toc-item"><a href="#Parámetros-de-las-funciones-de-masa/densidad" data-toc-modified-id="Parámetros-de-las-funciones-de-masa/densidad-222"><span class="toc-item-num">2.2.2&nbsp;&nbsp;</span>Parámetros de las funciones de masa/densidad</a></div><div class="lev2 toc-item"><a href="#Conjunta,-marginal,-condicional" data-toc-modified-id="Conjunta,-marginal,-condicional-23"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Conjunta, marginal, condicional</a></div><div class="lev2 toc-item"><a href="#¿Uso?" data-toc-modified-id="¿Uso?-24"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>¿Uso?</a></div>

# %%
import pandas as pd
import requests
import json
import numpy as np
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from IPython.display import Image, SVG
from scipy.misc import imread
import rasterio
import geopandas as gpd
import matplotlib.pyplot as plt

from IPython.core.display import HTML
HTML("""<style>
    p {font-size:18px;}
</style>""")

# %% [markdown]
# # Datos espaciales

# %% [markdown]
# ## Tipos y representaciones de datos
# * Procesos de puntos
# * Teselaciones

# %% [markdown]
# ## Procesos de puntos
# ### John Snow

# %%
cholera_img = Image(filename='imgs/Snow-cholera-map-1.jpg')

# %% [markdown]
# <a title="By John Snow [Public domain], via Wikimedia Commons" href="https://commons.wikimedia.org/wiki/File%3ASnow-cholera-map-1.jpg"><img width="512" alt="Snow-cholera-map-1" align="top" src="https://upload.wikimedia.org/wikipedia/commons/thumb/2/27/Snow-cholera-map-1.jpg/512px-Snow-cholera-map-1.jpg"/>
# </a><p> By John Snow
# </p>
# Published by C.F. Cheffins, Lith, Southhampton Buildings, London, England, 1854 in Snow, John. On the Mode of Communication of Cholera, 2nd Ed, John Churchill, New Burlington Street, London, England, 1855.

# %%
cholera_deaths_df = pd.read_csv('data/snow-cholera/Deaths.csv')
pumps_df = pd.read_csv('data/snow-cholera/Pumps.csv')

# %% [markdown]
# <p>Ubicaciones de muertes por cólera</p>

# %%
cholera_deaths_df.head()

# %% [markdown]
# Ubicaciones de bombas de agua

# %%
pumps_df.head()

# %%
img = imread("imgs/Snow-cholera-map-1.jpg")
snow_width = 2840/3
snow_height = 3045/3
fig, ax = plt.subplots()
ax.imshow(img, extent=[2.5, 20, 3, 19])

ax.plot(cholera_deaths_df.x, cholera_deaths_df.y, marker='o', lw=0, alpha=0.8)
fig.savefig("imgs/snow_map_muertes_col.jpeg")
plt.close()
cholera_img = Image(filename='imgs/snow_map_muertes_col.jpeg', width=snow_width, height=snow_height)

# %%
cholera_img

# %%
img = plt.imread("imgs/Snow-cholera-map-1.jpg")
fig, ax = plt.subplots()
ax.imshow(img, extent=[2.5, 20, 3, 19])

plt.plot(cholera_deaths_df.x, cholera_deaths_df.y, marker='o', lw=0, alpha=0.8)
plt.plot(pumps_df.x, pumps_df.y, marker='s', lw=0, alpha=0.8)
plt.savefig("imgs/snow_map_muertes_bombasagua.jpeg")
plt.close()

cholera_img = Image(filename='imgs/snow_map_muertes_bombasagua.jpeg', width=snow_width, height=snow_height)

# %%
cholera_img

# %%
img = plt.imread("imgs/snow_map.png")
fig, ax = plt.subplots()
ax.imshow(img, extent=[2.5, 20, 3, 19])

plt.plot(cholera_deaths_df.x, cholera_deaths_df.y, marker='o', lw=0, alpha=0.8)
plt.plot(pumps_df.x, pumps_df.y, marker='s', lw=0, alpha=0.8)
plt.grid()

plt.savefig("imgs/snow_map_mbgrid.png")
plt.close()
cholera_img = Image(filename='imgs/snow_map_mbgrid.png', width=snow_width, height=snow_height)

# %%
cholera_img

# %%
img = plt.imread("imgs/snow_map.png")
fig, ax = plt.subplots()
ax.imshow(img, extent=[2.5, 20, 3, 19])

plt.plot(cholera_deaths_df.x, cholera_deaths_df.y, marker='o', lw=0, alpha=0.8)
plt.plot(pumps_df.x, pumps_df.y, marker='s', lw=0, alpha=0.8)
plt.plot(pumps_df.x, pumps_df.y, marker='o', lw=0, alpha=0.3, markersize=50)

plt.savefig("imgs/snow_map_n1.jpeg", size=1024)
plt.close()
cholera_img = Image(filename='imgs/snow_map_n1.jpeg', width=snow_width, height=snow_height)

# %%
cholera_img

# %%
def death_toll(deaths, pumps, radius = 1):
    
    death_toll = []
    for i, p in pumps.iterrows():
        death_count = 0
        
        for j, d in deaths.iterrows():
            dist = ((p.x - d.x)**2 + (p.y - d.y)**2)**0.5
            if dist <= radius:
                death_count += 1
        
        death_toll.append(death_count)
    
    return death_toll

# %%
deaths = death_toll(cholera_deaths_df, pumps_df)

# %%
img = plt.imread("imgs/snow_map.png")
fig, ax = plt.subplots()
ax.imshow(img, extent=[2.5, 20, 3, 19])

ax.plot(cholera_deaths_df.x, cholera_deaths_df.y, marker='o', lw=0, alpha=0.8)
ax.plot(pumps_df.x, pumps_df.y, marker='s', lw=0, alpha=0.8)
ax.plot(pumps_df.x, pumps_df.y, marker='o', lw=0, alpha=0.3, markersize=30)

for label, x, y in zip(deaths, pumps_df.x, pumps_df.y):
    ax.annotate(
        label,
        xy=(x, y), xytext=(-20, 20),
        textcoords='offset points', ha='right', va='bottom',
        bbox=dict(boxstyle='round,pad=0.5', fc='yellow', alpha=0.5),
        arrowprops=dict(arrowstyle = '->', connectionstyle='arc3,rad=0'))

fig.savefig("imgs/snow_map_n1.png")
plt.close()
# https://stackoverflow.com/questions/5147112/matplotlib-how-to-put-individual-tags-for-a-scatter-plot

# %%
Image("imgs/snow_map_n1.png", width=snow_width, height=snow_height)

# %%
deaths = death_toll(cholera_deaths_df, pumps_df, 1.5)

# %%
img = plt.imread("imgs/snow_map.png")
fig, ax = plt.subplots()
ax.imshow(img, extent=[2.5, 20, 3, 19])

ax.plot(cholera_deaths_df.x, cholera_deaths_df.y, marker='o', lw=0, alpha=0.8)
ax.plot(pumps_df.x, pumps_df.y, marker='s', lw=0, alpha=0.8)
ax.plot(pumps_df.x, pumps_df.y, marker='o', lw=0, alpha=0.3, markersize=50)

for label, x, y in zip(deaths, pumps_df.x, pumps_df.y):
    ax.annotate(
        label,
        xy=(x, y), xytext=(-20, 20),
        textcoords='offset points', ha='right', va='bottom',
        bbox=dict(boxstyle='round,pad=0.5', fc='yellow', alpha=0.5),
        arrowprops=dict(arrowstyle = '->', connectionstyle='arc3,rad=0'))

fig.savefig("imgs/snow_map_n2.png")
plt.close()
# https://stackoverflow.com/questions/5147112/matplotlib-how-to-put-individual-tags-for-a-scatter-plot

# %%
Image("imgs/snow_map_n2.png", width=snow_width, height=snow_height)

# %% [markdown]
# ### Ejemplo datos reales: observaciones de jaguar
#
# Utilizaremos los servicios de datos de nuestra plataforma SPECIES

# %%
# funciones de utilidad
API_URL = u'http://species.conabio.gob.mx/api-dev/niche'
print(requests.get(API_URL).text)
def json_pretty_str(dict_obj):
    return json.dumps(dict_obj,
                     sort_keys=True,
                     indent=4,
                     separators=(',', ': '))

def desplegar_puntos(points_arr):
    min_coords = points_arr.min(axis=0)
    max_coords = points_arr.max(axis=0)

    ax = plt.axes(projection=ccrs.PlateCarree())
    ax.set_extent([-120, -86, 10, 40])
    # ax.stock_img()
    # ax.add_feature(cfeature.LAND)
    # ax.add_feature(cfeature.OCEAN)
    # ax.coastlines()
    ax.scatter(points_arr[:,0],points_arr[:,1],transform=ccrs.PlateCarree(), zorder=4, marker='.')
    
    plt.show()

def obtener_puntos_especie(nom_especie):
    spid = obtener_id_especie(nom_especie)
    # Ya con el ID de especie del jaguar (SPID), pedimos todos los registros que hay en la base de datos
    query = {
        "qtype": "getSpecies",
        "id": spid,
        'sfecha': 'false',
        'sfosil': 'false'
    }

    r = requests.post(API_URL+'/especie', params=query)
    print(r)
    
    response = json.loads(r.content)
    print(json_pretty_str(response['data'][:3]))

    points = [json.loads(e['json_geom'])['coordinates'] for e in response['data']]
    points_arr = np.array(points)
    
    return points_arr

def obtener_id_especie(nom_especie):
    query = {
        "qtype":"getEntList",
        "searchStr":nom_especie, # Nombre de la especie substring de la especie a buscar
        "nivel":"especievalidabusqueda",
        "source":1
    }
    r = requests.post(API_URL+'/especie', params=query)

    response = json.loads(r.content)
    species_md = response['data'][0]
    print(json_pretty_str(species_md))
    
    return species_md['spid']

# %%
obs_jaguar = obtener_puntos_especie('Panthera onca')

# %%
# desplegar_puntos(obs_jaguar)

# %% [markdown]
# # Probabilidad y estadística
# ## Variables aleatorias
#
# ## Funciones de densidad/masa de probabilidad
# ### Uniforme, Bernoulli, Binomial
# ### Parámetros de las funciones de masa/densidad
#
# ## Conjunta, marginal, condicional

# %% [markdown]
# ## ¿Uso?
# Describir sistemas naturales mediante variables aleatorias y distribuciones de probabilidad. Descirbir el resultado de preocesos ecológicos mediante variables aleatorias donde las distribuciones de probabilidad describen la variabilidad en dichos procesos. La probabilidad es la base conceptual para modelar.

# %% [raw]
# <script>
#   $(document).ready(function(){
#     $('div.prompt').hide();
#     $('div.back-to-top').hide();
#     $('nav#menubar').hide();
#     $('.breadcrumb').hide();
#     $('.hidden-print').hide();
#   });
# </script>
#
# <footer id="attribution" style="float:right; color:#999; background:#fff;">
# Created with Jupyter, delivered by Fastly, rendered by Rackspace.
# </footer>
